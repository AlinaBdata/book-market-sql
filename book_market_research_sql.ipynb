# %% [markdown]
# # Book market research

# %% [markdown]
# *This is an assignment given as part of the graduation project for Yandex100 program.
#
# This is not a whole project but only an example of some SQL queries I have written.*

# %% [markdown]
# **This is a study of book services apps. It will be used to prepare a value proposition for a new app for book lovers.
# The database contains data on books, publishers, authors, and customer ratings and reviews of books.**

# %%
# ! pip install PyMySQL

# %%
# import libraries
import pandas as pd
import matplotlib.pyplot as plt
from sqlalchemy import create_engine
import pymysql

# %%
#connect to database
db_config = {'user':'some_user',         # user name
             'pwd': 'somepassword', # password
             'host':'some.local.host.net',
             'port':1234,              # connection port
             'db': 'books-db'} # the name of the data base

connection_string = 'postgresql://{}:{}@{}:{}/{}'.format(db_config['user'],
                                                         db_config['pwd'],
                                                         db_config['host'],
                                                         db_config['port'],
                                                         db_config['db'])

engine = create_engine(connection_string, connect_args={'sslmode':'require'})

# %%
connection = engine.connect()

# %% [markdown]
# ### Study the data

# %%
engine.table_names()
# Out:
# ['orders',
#  'visits',
#  'advertisment_costs',
#  'publishers',
#  'authors',
#  'reviews',
#  'ratings',
#  'books']

# %%
books = f'''SELECT *
FROM books'''

# %%
books_load = pd.read_sql(books,engine)

display(books_load.head())
books_load.info()
# Out:
#    book_id  author_id                                              title  \
# 0        1        546                                       'Salem's Lot
# 1        2        465                 1 000 Places to See Before You Die
# 2        3        407  13 Little Blue Envelopes (Little Blue Envelope...
# 3        4         82  1491: New Revelations of the Americas Before C...
# 4        5        125                                               1776
#
#    num_pages publication_date  publisher_id
# 0        594       2005-11-01            93
# 1        992       2003-05-22           336
# 2        322       2010-12-21           135
# 3        541       2006-10-10           309
# 4        386       2006-07-04           268
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
# book_id             1000 non-null int64
# author_id           1000 non-null int64
# title               1000 non-null object
# num_pages           1000 non-null int64
# publication_date    1000 non-null object
# publisher_id        1000 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 47.0+ KB

# %%
authors = f'''
SELECT *
FROM authors'''

# %%
authors_load = pd.read_sql(authors, engine)

display(authors_load.head())
authors_load.info()
# Out:
#    author_id                          author
# 0          1                      A.S. Byatt
# 1          2  Aesop/Laura Harris/Laura Gibbs
# 2          3                 Agatha Christie
# 3          4                   Alan Brennert
# 4          5        Alan Moore/David   Lloyd
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 636 entries, 0 to 635
# Data columns (total 2 columns):
# author_id    636 non-null int64
# author       636 non-null object
# dtypes: int64(1), object(1)
# memory usage: 10.1+ KB

# %%
publishers = f'''
SELECT *
FROM publishers'''

# %%
publishers_load = pd.read_sql(publishers, engine)

display(publishers_load.head())
publishers_load.info()
# Out:
#    publisher_id                          publisher
# 0             1                                Ace
# 1             2                           Ace Book
# 2             3                          Ace Books
# 3             4                      Ace Hardcover
# 4             5  Addison Wesley Publishing Company
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 340 entries, 0 to 339
# Data columns (total 2 columns):
# publisher_id    340 non-null int64
# publisher       340 non-null object
# dtypes: int64(1), object(1)
# memory usage: 5.4+ KB

# %%
reviews = f'''
SELECT *
FROM reviews'''

# %%
reviews_load = pd.read_sql(reviews, engine)

display(reviews_load.head())
reviews_load.info()
# Out:
#    review_id  book_id       username  \
# 0          1        1   brandtandrea
# 1          2        1     ryanfranco
# 2          3        2       lorichen
# 3          4        3  johnsonamanda
# 4          5        3    scotttamara
#
#                                                 text
# 0  Mention society tell send professor analysis. ...
# 1  Foot glass pretty audience hit themselves. Amo...
# 2  Listen treat keep worry. Miss husband tax but ...
# 3  Finally month interesting blue could nature cu...
# 4  Nation purpose heavy give wait song will. List...
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2793 entries, 0 to 2792
# Data columns (total 4 columns):
# review_id    2793 non-null int64
# book_id      2793 non-null int64
# username     2793 non-null object
# text         2793 non-null object
# dtypes: int64(2), object(2)
# memory usage: 87.4+ KB

# %%
ratings = f'''
SELECT *
FROM ratings'''

# %%
ratings_load = pd.read_sql(ratings, engine)

display(ratings_load.head())
ratings_load.info()
# Out:
#    rating_id  book_id       username  rating
# 0          1        1     ryanfranco       4
# 1          2        1  grantpatricia       2
# 2          3        1   brandtandrea       5
# 3          4        2       lorichen       3
# 4          5        2    mariokeller       2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6456 entries, 0 to 6455
# Data columns (total 4 columns):
# rating_id    6456 non-null int64
# book_id      6456 non-null int64
# username     6456 non-null object
# rating       6456 non-null int64
# dtypes: int64(3), object(1)
# memory usage: 201.9+ KB

# %% [markdown]
# ### SQL queries

# %% [markdown]
# **Find the number of books released after January 1, 2000**

# %%
query_one = f'''
SELECT COUNT(book_id) AS book_count
FROM books
WHERE CAST (publication_date AS date) > '2000-01-01';
'''

# %%
new_books = pd.read_sql(query_one,engine)
new_books
# Out:
#    book_count
# 0         819

# %% [markdown]
# Out of 1,000 books in the database 819 were published after January 1, 2000.
# This database mostly consists of relatively new books, not classics.

# %% [markdown]
# **Find the number of user reviews and the average rating for each book**

# %%
query_two_1 = f'''
SELECT 
    DISTINCT books.book_id AS book_id,
    books.title AS title,
    COUNT(DISTINCT reviews.review_id) AS review_count,
    AVG(ratings.rating) AS avg_rating 
FROM
    books
INNER JOIN reviews ON reviews.book_id = books.book_id
INNER JOIN ratings ON ratings.book_id = books.book_id
GROUP BY 
    books.book_id
ORDER BY review_count DESC
LIMIT 20;

'''

# %%
reviews_ratings_1 = pd.read_sql(query_two_1,engine)
reviews_ratings_1
# Out:
#     book_id                                              title  review_count  \
# 0       948                            Twilight (Twilight  #1)             7
# 1       207                                    Eat  Pray  Love             6
# 2       299  Harry Potter and the Chamber of Secrets (Harry...             6
# 3       302  Harry Potter and the Prisoner of Azkaban (Harr...             6
# 4       497                          Outlander (Outlander  #1)             6
# 5       627                                      The Alchemist             6
# 6       656                                     The Book Thief             6
# 7       673                             The Catcher in the Rye             6
# 8       695  The Curious Incident of the Dog in the Night-Time             6
# 9       696             The Da Vinci Code (Robert Langdon  #2)             6
# 10      733                          The Giver (The Giver  #1)             6
# 11      734                                   The Glass Castle             6
# 12      750                The Hobbit  or There and Back Again             6
# 13      779  The Lightning Thief (Percy Jackson and the Oly...             6
# 14      854                                           The Road             6
# 15      963                                Water for Elephants             6
# 16       15     A Clash of Kings  (A Song of Ice and Fire  #2)             5
# 17       51                           A Tree Grows in Brooklyn             5
# 18       52  A Walk in the Woods: Rediscovering America on ...             5
# 19       70                  American Gods (American Gods  #1)             5
#
#     avg_rating
# 0     3.662500
# 1     3.395833
# 2     4.287500
# 3     4.414634
# 4     4.125000
# 5     3.789474
# 6     4.264151
# 7     3.825581
# 8     4.081081
# 9     3.830508
# 10    3.750000
# 11    4.206897
# 12    4.125000
# 13    4.080645
# 14    3.772727
# 15    3.977273
# 16    4.391304
# 17    4.250000
# 18    3.636364
# 19    4.000000

# %%
query_two_2 = f'''
SELECT 
    DISTINCT books.book_id AS book_id,
    books.title AS title,
    COUNT(DISTINCT reviews.review_id) AS review_count,
    AVG(ratings.rating) AS avg_rating 
FROM
    books
INNER JOIN reviews ON reviews.book_id = books.book_id
INNER JOIN ratings ON ratings.book_id = books.book_id
GROUP BY 
    books.book_id
ORDER BY avg_rating DESC
LIMIT 50;

'''

# %%
reviews_ratings_2 = pd.read_sql(query_two_2,engine)
reviews_ratings_2
# Out:
#     book_id                                              title  review_count  \
# 0        17                      A Dirty Job (Grim Reaper  #1)             4
# 1        20              A Fistful of Charms (The Hollows  #4)             2
# 2        55          A Woman of Substance (Emma Harte Saga #1)             2
# 3        57                    Act of Treason (Mitch Rapp  #9)             2
# 4        62                                      Alas  Babylon             2
# 5        76                                        Angels Fall             2
# 6        86      Arrows of the Queen (Heralds of Valdemar  #1)             2
# 7       136  Captivating: Unveiling the Mystery of a Woman'...             2
# 8       169  Crucial Conversations: Tools for Talking When ...             2
# 9       182                                         Dead Souls             2
# 10      213                      Emily of New Moon (Emily  #1)             2
# 11      224                                      Evening Class             2
# 12      229           Evil Under the Sun (Hercule Poirot  #24)             2
# 13      275                                          Geek Love             2
# 14      297                                         Hard Times             2
# 15      321                                Homage to Catalonia             2
# 16      330  How to Be a Domestic Goddess: Baking and the A...             1
# 17      347  In the Hand of the Goddess (Song of the Liones...             2
# 18      390                                    Light in August             2
# 19      418                                              March             2
# 20      421                                        Marvel 1602             2
# 21      441                  Misty of Chincoteague (Misty  #1)             2
# 22      444       Moneyball: The Art of Winning an Unfair Game             3
# 23      459                               My Name Is Asher Lev             2
# 24      469                           Neil Gaiman's Neverwhere             2
# 25      513               Piercing the Darkness (Darkness  #2)             2
# 26      516                       Plum Island (John Corey  #1)             2
# 27      518               Pop Goes the Weasel (Alex Cross  #5)             2
# 28      553            School's Out—Forever (Maximum Ride  #2)             3
# 29      598               Stolen (Women of the Otherworld  #2)             2
# 30      599  Stone of Farewell (Memory  Sorrow  and Thorn  #2)             1
# 31      610                           Tai-Pan (Asian Saga  #2)             2
# 32      625  The Adventures of Tom Sawyer and Adventures of...             1
# 33      642                 The Big Bad Wolf  (Alex Cross  #9)             2
# 34      699  The Demon-Haunted World: Science as a Candle i...             2
# 35      732  The Ghost Map: The Story of London's Most Terr...             2
# 36      901  The Walking Dead  Book One (The Walking Dead #...             2
# 37      902  The War of Art: Break Through the Blocks & Win...             2
# 38      913                                 The Woman in Black             2
# 39      938                          Triptych (Will Trent  #1)             2
# 40      967               Welcome to Temptation (Dempseys  #1)             2
# 41      972  Wherever You Go  There You Are: Mindfulness Me...             2
# 42      993                                              Women             2
# 43      195                 Dragonfly in Amber (Outlander  #2)             4
# 44      524             Preludes & Nocturnes (The Sandman  #1)             3
# 45      327                                    House of Leaves             4
# 46      411      Lover Revealed (Black Dagger Brotherhood  #4)             3
# 47      801                The Monster at the End of this Book             3
# 48      890                                          The Twits             3
# 49      912  The Witching Hour (Lives of the Mayfair Witche...             3
#
#     avg_rating
# 0     5.000000
# 1     5.000000
# 2     5.000000
# 3     5.000000
# 4     5.000000
# 5     5.000000
# 6     5.000000
# 7     5.000000
# 8     5.000000
# 9     5.000000
# 10    5.000000
# 11    5.000000
# 12    5.000000
# 13    5.000000
# 14    5.000000
# 15    5.000000
# 16    5.000000
# 17    5.000000
# 18    5.000000
# 19    5.000000
# 20    5.000000
# 21    5.000000
# 22    5.000000
# 23    5.000000
# 24    5.000000
# 25    5.000000
# 26    5.000000
# 27    5.000000
# 28    5.000000
# 29    5.000000
# 30    5.000000
# 31    5.000000
# 32    5.000000
# 33    5.000000
# 34    5.000000
# 35    5.000000
# 36    5.000000
# 37    5.000000
# 38    5.000000
# 39    5.000000
# 40    5.000000
# 41    5.000000
# 42    5.000000
# 43    4.875000
# 44    4.833333
# 45    4.750000
# 46    4.750000
# 47    4.750000
# 48    4.750000
# 49    4.750000

# %% [markdown]
# We can see that books with 5.0 rating have relatively low amount of reviews. The most reviewed book has 7 reviews.
# We can conclude that the more reviews a book gets, the more chances that it gets a lower rating. This makes sense- the more opinions there are, the more diverse those opinions are.

# %% [markdown]
# **Identify the publisher that has released the greatest number of books with more than 50 pages (this will help you exclude brochures and similar publications from your analysis)**

# %%
query_three = f'''
SELECT 
    publishers.publisher AS publisher,
    COUNT(books.book_id)
FROM
    books
INNER JOIN publishers ON books.publisher_id = publishers.publisher_id
WHERE books.num_pages > 50
GROUP BY publishers.publisher
ORDER BY count DESC
LIMIT 1;
'''

# %%
biggest_publisher = pd.read_sql(query_three,engine)
biggest_publisher
# Out:
#        publisher  count
# 0  Penguin Books     42

# %% [markdown]
# Penguin Books is the largest publisher here.

# %% [markdown]
# **Identify the author with the highest average book rating (look only at books with at least 50 ratings)**

# %%
query_four = f'''
SELECT 
    authors.author AS author_name,
    AVG(SUBQ.avg_rating) AS avg_rating
FROM
    (SELECT DISTINCT ratings.book_id,
            AVG(ratings.rating) AS avg_rating,
            COUNT(ratings.rating_id) AS cnt_ratings
     FROM ratings
     GROUP BY ratings.book_id) AS SUBQ
INNER JOIN books ON SUBQ.book_id = books.book_id
INNER JOIN authors ON books.author_id = authors.author_id
WHERE SUBQ.cnt_ratings >= 50
GROUP BY authors.author
ORDER BY avg_rating DESC
LIMIT 1;
'''

# %%
most_rated_author = pd.read_sql(query_four, engine)
most_rated_author
# Out:
#                   author_name  avg_rating
# 0  J.K. Rowling/Mary GrandPré    4.283844

# %% [markdown]
# The highest rated author in J.K. Rowling (and the illustrator of the U.S edition of Harry Potter books). No surprise here :)

# %% [markdown]
# **Find the average number of text reviews among users who rated more than 50 books**

# %%
query_five = f'''
SELECT
    AVG(SUBQ.cnt_reviews) AS average_number
FROM
    (SELECT  
        COUNT(DISTINCT reviews.review_id) AS cnt_reviews  
        FROM reviews
        LEFT JOIN ratings ON ratings.username = reviews.username
        GROUP BY reviews.username
        HAVING COUNT(DISTINCT ratings.rating_id) > 50) AS SUBQ
        ;    
'''

# %%
top_reviewer = pd.read_sql(query_five, engine)
top_reviewer
# Out:
#    average_number
# 0       24.333333

# %% [markdown]
# The average number of text reviews for the top rating users is 24.3 reviews.
